# %%
import pandas as pd
import numpy as np
import json

# %%
# import data
with open("./animeInfo/animeInfo0.txt") as file:
    
    wow = file.readline()
    
json.loads(wow)
# Out:
# [{'name': None,
#   'producers': ['Aniplex',
#    'SquareEnix',
#    'MainichiBroadcastingSystem',
#    'StudioMoriken'],
#   'ranking': 1,
#   'votersCount': 1629051,
#   'score': 9.16,
#   'popularity': 3,
#   'members': 2689113,
#   'favorite': 189880,
#   'episodes': 64,
#   'animeType': 'TV',
#   'premiredDate': 'Spring 2009',
#   'animeSource': 'Manga',
#   'genres': ['ActionAction',
#    'AdventureAdventure',
#    'ComedyComedy',
#    'DramaDrama',
#    'FantasyFantasy'],
#   'studios': 'Bones',
#   'licenses': ['Funimation', 'AniplexofAmerica'],
#   'rating': 'R-17+',
#   'voiceActorNameandLanguage': [['Kugimiya,Rie', 'Japanese'],
#    ['Ponticelli,Benedetta', 'Italian'],
#    ['Andreatto,Rodrigo', 'Portuguese(BR)'],
#    ['Gerick,Wanja', 'German'],
#    ['Baráth,István', 'Hungarian'],
#    ['Whitehead,Maxey', 'English'],
#    ['Yun,MiNa', 'Korean'],
#    ['Truncale,Lily', 'English'],
#    ['Torres,Jhonny', 'Spanish'],
#    ['Pic,Audrey', 'French'],
# ...
