# %%
import pandas as pd
import re
import numpy as np

# %%
df = pd.read_csv("animeInfoComp.csv")

# %%
pd.set_option("display.max_columns", 19)

# %%
df.head()
# Out:
#                                  name  \
# 0    Fullmetal Alchemist: Brotherhood
# 1                             Gintama
# 2  Shingeki no Kyojin Season 3 Part 2
# 3                         Steins;Gate
# 4            Fruits Basket: The Final
#
#                                            producers  ranking  votersCount  \
# 0  ['Aniplex', 'SquareEnix', 'MainichiBroadcastin...        1      1629051
# 1                   ['TVTokyo', 'Aniplex', 'Dentsu']        2       171695
# 2  ['ProductionI.G', 'Dentsu', 'MainichiBroadcast...        3      1108307
# 3  ['FrontierWorks', 'MediaFactory', 'Movic', 'AT...        4      1115839
# 4  ['TVTokyo', 'TVOsaka', 'NihonAdSystems', 'Haku...        5       118724
#
#    score  popularity  members  favorite  episodes animeType premiredDate  \
# 0   9.16           3  2689113    189880      64.0        TV  Spring 2009
# 1   9.09         336   487203     12881      51.0        TV  Spring 2015
# 2   9.09          33  1610148     45597      10.0        TV  Spring 2019
# 3   9.09          12  2100262    160985      24.0        TV  Spring 2011
# 4   9.06         630   279831     12851      13.0        TV  Spring 2021
#
#     animeSource                                             genres  \
# 0         Manga  ['ActionAction', 'AdventureAdventure', 'Comedy...
# 1         Manga   ['ActionAction', 'ComedyComedy', 'Sci-FiSci-Fi']
# 2         Manga  ['ActionAction', 'DramaDrama', 'FantasyFantasy...
# 3  Visual novel  ['DramaDrama', 'Sci-FiSci-Fi', 'SuspenseSuspen...
# 4         Manga  ['ComedyComedy', 'DramaDrama', 'RomanceRomance...
#
#                  studios                            licenses       rating  \
# 0                  Bones  ['Funimation', 'AniplexofAmerica']        R-17+
# 1  Bandai Namco Pictures       ['Funimation', 'Crunchyroll']  PG-13-Teens
# 2             Wit Studio                      ['Funimation']        R-17+
# 3              White Fox                      ['Funimation']  PG-13-Teens
# 4      TMS Entertainment                      ['Funimation']  PG-13-Teens
#
#                            voiceActorNameandLanguage  \
# 0  [['Kugimiya,Rie', 'Japanese'], ['Ponticelli,Be...
# 1  [['Kugimiya,Rie', 'Japanese'], ['Ishii,Kouji',...
# 2  [['Ishikawa,Yui', 'Japanese'], ['Perino,Elena'...
# 3  [['Seki,Tomokazu', 'Japanese'], ['Rinehart,Tys...
# 4  [['Iwami,Manaka', 'Japanese'], ['Uchida,Yuuma'...
#
#                               staffNameandOccupation
# 0  [['Cook,Justin', 'Producer'], ['Yonai,Noritomo...
# 1  [['Fujita,Youichi', 'Director,Storyboard,Plann...
# 2  [['Morishita,Katsuji', 'Producer,Planning'], [...
# 3  [['Iwasa,Gaku', 'Producer'], ['Yasuda,Takeshi'...
# 4  [['Ibata,Yoshihide', 'Director'], ['Aketagawa,...

# %%
re.sub(r",\'", r";", df["producers"][0][1:-1])
# Out:
# "'Aniplex', 'SquareEnix', 'MainichiBroadcastingSystem', 'StudioMoriken'"

# %%
def remove_quote(word):
    return word.replace("'","")

# %%
def remove_openBracket(word):
    return word.replace("[","")

# %%
def remove_closeBracket(word):
    return word.replace("]","")

# %%
def remove_commaWithSemicolon(word):
    return word.replace(",",";")

# %%
def remove_space(word):
    return word.replace(" ","")

# %%
# remove extra things that we don't need from producers
df["producers"] = remove_quote(df["producers"].str)
df["producers"] = remove_openBracket(df["producers"].str)
df["producers"] = remove_closeBracket(df["producers"].str)
df["producers"] = remove_commaWithSemicolon(df["producers"].str)
df["producers"] = remove_space(df["producers"].str)
# Out:
# <ipython-input-262-0ec24dd68035>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   return word.replace("[","")

# %%
df["producers"][0]
# Out:
# 'Aniplex;SquareEnix;MainichiBroadcastingSystem;StudioMoriken'

# %%
# remove extra things from genre
df["genres"] = remove_quote(df["genres"].str)
df["genres"] = remove_openBracket(df["genres"].str)
df["genres"] = remove_closeBracket(df["genres"].str)
df["genres"] = remove_commaWithSemicolon(df["genres"].str)
df["genres"] = remove_space(df["genres"].str)
# Out:
# <ipython-input-262-0ec24dd68035>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   return word.replace("[","")

# %%
# remove extra things from license
df["licenses"] = remove_quote(df["licenses"].str)
df["licenses"] = remove_openBracket(df["licenses"].str)
df["licenses"] = remove_closeBracket(df["licenses"].str)
df["licenses"] = remove_commaWithSemicolon(df["licenses"].str)
df["licenses"] = remove_space(df["licenses"].str)
# Out:
# <ipython-input-262-0ec24dd68035>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   return word.replace("[","")

# %%
df.head(20)
# Out:
#                                                  name  \
# 0                    Fullmetal Alchemist: Brotherhood
# 1                                             Gintama
# 2                  Shingeki no Kyojin Season 3 Part 2
# 3                                         Steins;Gate
# 4                            Fruits Basket: The Final
# 5                                            Gintama'
# 6                              Hunter x Hunter (2011)
# 7                                Ginga Eiyuu Densetsu
# 8                                 Gintama': Enchousen
# 9                                  Gintama: The Final
# 10                                           Gintama.
# 11                         3-gatsu no Lion 2nd Season
# 12                                     Koe no Katachi
# 13                            Violet Evergarden Movie
# 14                               Clannad: After Story
# 15                                            Gintama
# 16  Gintama Movie 2: Kanketsu-hen - Yorozuya yo Ei...
# 17                 Code Geass: Hangyaku no Lelouch R2
# 18                         Owarimonogatari 2nd Season
# 19               Shingeki no Kyojin: The Final Season
#
#                                             producers  ranking  votersCount  \
# 0   Aniplex;SquareEnix;MainichiBroadcastingSystem;...      1.0    1629051.0
# 1                              TVTokyo;Aniplex;Dentsu      2.0     171695.0
# 2   ProductionI.G;Dentsu;MainichiBroadcastingSyste...      3.0    1108307.0
# 3   FrontierWorks;MediaFactory;Movic;AT-X;Kadokawa...      4.0    1115839.0
# 4   TVTokyo;TVOsaka;NihonAdSystems;Hakusensha;Avex...      5.0     118724.0
# 5   TVTokyo;Aniplex;Dentsu;TrinitySound;MiracleRob...      6.0     179859.0
# 6                VAP;NipponTelevisionNetwork;Shueisha      7.0    1263852.0
# 7   TVTokyo;KittyFilms;TokumaShoten;TokumaJapanCom...      8.0      58559.0
# 8          TVTokyo;Aniplex;Dentsu;Shueisha;MiracleBus      9.0     130909.0
# 9                            TVTokyo;WarnerBros.Japan     10.0      31826.0
# 10                    TVTokyo;Aniplex;Dentsu;Shueisha     11.0     110051.0
# 11  Aniplex;Dentsu;NHK;Hakusensha;AsmikAce;"ToysFa...     12.0     156965.0
# 12   Shochiku;PonyCanyon;Kodansha;ABCAnimation;Quaras     13.0    1227199.0
# 13                                           Shochiku     14.0     104401.0
# 14               PonyCanyon;TBS;Rakuonsha;AnimationDo     15.0     570222.0
# 15  TVTokyo;Aniplex;Dentsu;TrinitySound;AudioHighs...     16.0     265054.0
# 16  TVTokyo;Aniplex;Dentsu;Bandai;WarnerBros.Japan...     17.0     110861.0
# 17  BandaiVisual;MainichiBroadcastingSystem;Bandai...     18.0     985084.0
# 18                                   Aniplex;Kodansha     19.0     152042.0
# 19  ProductionI.G;Dentsu;MainichiBroadcastingSyste...     20.0     812495.0
#
#     score  popularity    members  favorite  episodes animeType premiredDate  \
# 0    9.16         3.0  2689113.0  189880.0      64.0        TV  Spring 2009
# 1    9.09       336.0   487203.0   12881.0      51.0        TV  Spring 2015
# 2    9.09        33.0  1610148.0   45597.0      10.0        TV  Spring 2019
# 3    9.09        12.0  2100262.0  160985.0      24.0        TV  Spring 2011
# 4    9.06       630.0   279831.0   12851.0      13.0        TV  Spring 2021
# 5    9.06       381.0   431071.0    6466.0      51.0        TV  Spring 2011
# 6    9.06        10.0  2164151.0  166695.0     148.0        TV    Fall 2011
# 7    9.04       680.0   264114.0   13780.0     110.0       OVA          NaN
# 8    9.03       684.0   262390.0    2597.0      13.0        TV    Fall 2012
# 9    9.01      1902.0    80839.0    2900.0       1.0     Movie          NaN
# 10   8.98       723.0   247686.0    2363.0      12.0        TV  Winter 2017
# 11   8.97       526.0   325996.0   12987.0      22.0        TV    Fall 2017
# 12   8.97        23.0  1791624.0   68789.0       1.0     Movie          NaN
# 13   8.97       491.0   347050.0    4405.0       1.0     Movie          NaN
# 14   8.95       100.0  1028940.0   63871.0      24.0        TV    Fall 2008
# 15   8.95       123.0   890585.0   51543.0     201.0        TV  Spring 2006
# 16   8.94       924.0   196868.0    1956.0       1.0     Movie          NaN
# 17   8.91        46.0  1474898.0   67065.0      25.0        TV  Spring 2008
# 18   8.91       529.0   324908.0    7365.0       7.0        TV  Summer 2017
# 19   8.90        57.0  1359598.0   48207.0      16.0        TV  Winter 2021
#
#      animeSource                                          genres  \
# 0          Manga           Action;Adventure;Comedy;Drama;Fantasy
# 1          Manga                            Action;Comedy;Sci-fi
# 2          Manga                    Action;Drama;Fantasy;Mystery
# 3   Visual novel                           Drama;Sci-fi;Suspense
# 4          Manga  Comedy;Drama;Romance;Sliceof;Life;Supernatural
# 5          Manga                            Action;Comedy;Sci-fi
# 6          Manga                        Action;Adventure;Fantasy
# 7          Novel                                    Drama;Sci-fi
# 8          Manga                            Action;Comedy;Sci-fi
# 9          Manga                      Action;Comedy;Drama;Sci-fi
# 10         Manga                            Action;Comedy;Sci-fi
# 11         Manga                              Drama;Sliceof;Life
# 12         Manga
# 13   Light novel                      Drama;Fantasy;Sliceof;Life
# 14  Visual novel  Comedy;Drama;Romance;Sliceof;Life;Supernatural
# 15         Manga                            Action;Comedy;Sci-fi
# 16         Manga                            Action;Comedy;Sci-fi
# 17      Original                             Action;Drama;Sci-fi
# 18   Light novel                     Comedy;Mystery;Supernatural
# 19         Manga                    Action;Drama;Fantasy;Mystery
#
#                                 studios                        licenses  \
# 0                                 Bones     Funimation;AniplexofAmerica
# 1                 Bandai Namco Pictures          Funimation;Crunchyroll
# 2                            Wit Studio                      Funimation
# 3                             White Fox                      Funimation
# 4                     TMS Entertainment                      Funimation
# 5                               Sunrise                             NaN
# 6                              Madhouse                        VIZMedia
# 7   K-Factory, Kitty Film Mitaka Studio                 SentaiFilmworks
# 8                               Sunrise                             NaN
# 9                 Bandai Namco Pictures                      ElevenArts
# 10                Bandai Namco Pictures                             NaN
# 11                                Shaft                AniplexofAmerica
# 12                      Kyoto Animation             ElevenArts;NYAVPost
# 13                      Kyoto Animation                      Funimation
# 14                      Kyoto Animation                 SentaiFilmworks
# 15                              Sunrise     SentaiFilmworks;Crunchyroll
# 16                              Sunrise                             NaN
# 17                              Sunrise  Funimation;BandaiEntertainment
# 18                                Shaft                AniplexofAmerica
# 19                                MAPPA                      Funimation
#
#          rating                          voiceActorNameandLanguage  \
# 0         R-17+  [['Kugimiya,Rie', 'Japanese'], ['Ponticelli,Be...
# 1   PG-13-Teens  [['Kugimiya,Rie', 'Japanese'], ['Ishii,Kouji',...
# 2         R-17+  [['Ishikawa,Yui', 'Japanese'], ['Perino,Elena'...
# 3   PG-13-Teens  [['Seki,Tomokazu', 'Japanese'], ['Rinehart,Tys...
# 4   PG-13-Teens  [['Iwami,Manaka', 'Japanese'], ['Uchida,Yuuma'...
# 5   PG-13-Teens  [['Kugimiya,Rie', 'Japanese'], ['Sugita,Tomoka...
# 6   PG-13-Teens  [['Berger,Jackie', 'French'], ['Han,Megumi', '...
# 7         R-17+  [['Inoue,Kazuhiko', 'Japanese'], ['Sakakibara,...
# 8   PG-13-Teens  [['Kugimiya,Rie', 'Japanese'], ['Sugita,Tomoka...
# 9   PG-13-Teens  [['Sugita,Tomokazu', 'Japanese'], ['Hino,Satos...
# 10  PG-13-Teens  [['Kugimiya,Rie', 'Japanese'], ['Ishida,Akira'...
# 11  PG-13-Teens  [['Kuno,Misaki', 'Japanese'], ['Huynh,Xanthe',...
# 12  PG-13-Teens  [['Irino,Miyu', 'Japanese'], ['Matsuoka,Mayu',...
# 13  PG-13-Teens  [['Donnay,Maxime', 'French'], ['Ishikawa,Yui',...
# 14  PG-13-Teens  [['Nakahara,Mai', 'Japanese'], ['Christian,Luc...
# 15  PG-13-Teens  [['Kugimiya,Rie', 'Japanese'], ['Mun,Seonhui',...
# 16  PG-13-Teens  [['Kugimiya,Rie', 'Japanese'], ['Möller,KayaMa...
# 17        R-17+  [['Yukana', 'Japanese'], ['Higgins,Kate', 'Eng...
# 18        R-17+  [['Kamiya,Hiroshi', 'Japanese'], ['Katou,Emiri...
# 19        R-17+  [['Ishikawa,Yui', 'Japanese'], ['Stefane,Mayar...
#
#                                staffNameandOccupation
# 0   [['Cook,Justin', 'Producer'], ['Yonai,Noritomo...
# 1   [['Fujita,Youichi', 'Director,Storyboard,Plann...
# 2   [['Morishita,Katsuji', 'Producer,Planning'], [...
# 3   [['Iwasa,Gaku', 'Producer'], ['Yasuda,Takeshi'...
# 4   [['Ibata,Yoshihide', 'Director'], ['Aketagawa,...
# 5   [['Fujita,Youichi', 'Director,EpisodeDirector,...
# 6   [['Maruyama,Masao', 'Producer'], ['Nakatani,To...
# 7   [['Ishiguro,Noboru', 'Director,EpisodeDirector...
# 8   [['Fujita,Youichi', 'Director,EpisodeDirector,...
# 9   [['Fujita,Youichi', 'Director'], ['Miyawaki,Ch...
# 10  [['Fujita,Youichi', 'Director'], ['Miyawaki,Ch...
# 11  [['Okada,Kenjirou', 'Director,EpisodeDirector,...
# 12  [['Senami,Riri', 'AssistantProducer'], ['Yamad...
# 13  [['Karasawa,Miho', 'ThemeSongPerformance'], ['...
# 14  [['Hatta,Youko', 'Producer'], ['Nakamura,Shini...
# 15  [['Takamatsu,Shinji', 'Co-Director,Director,St...
# 16  [['Fujita,Youichi', 'Director,EpisodeDirector,...
# 17  [['Maseba,Yutaka', 'Producer'], ['Taniguchi,Go...
# 18  [['Itamura,Tomoyuki', 'Director,EpisodeDirecto...
# 19  [['Hayashi,Yuuichirou', 'Director,Storyboard']...

# %%
newdf = pd.DataFrame(df["genres"].str.split(';'))

# %%
newdf.head(20)
# Out:
#                                                genres
# 0   [ActionAction, AdventureAdventure, ComedyComed...
# 1          [ActionAction, ComedyComedy, Sci-FiSci-Fi]
# 2   [ActionAction, DramaDrama, FantasyFantasy, Mys...
# 3        [DramaDrama, Sci-FiSci-Fi, SuspenseSuspense]
# 4   [ComedyComedy, DramaDrama, RomanceRomance, Sli...
# 5          [ActionAction, ComedyComedy, Sci-FiSci-Fi]
# 6   [ActionAction, AdventureAdventure, FantasyFant...
# 7                          [DramaDrama, Sci-FiSci-Fi]
# 8          [ActionAction, ComedyComedy, Sci-FiSci-Fi]
# 9   [ActionAction, ComedyComedy, DramaDrama, Sci-F...
# 10         [ActionAction, ComedyComedy, Sci-FiSci-Fi]
# 11               [DramaDrama, SliceofLifeSliceofLife]
# 12                                                NaN
# 13  [DramaDrama, FantasyFantasy, SliceofLifeSliceo...
# 14  [ComedyComedy, DramaDrama, RomanceRomance, Sli...
# 15         [ActionAction, ComedyComedy, Sci-FiSci-Fi]
# 16         [ActionAction, ComedyComedy, Sci-FiSci-Fi]
# 17           [ActionAction, DramaDrama, Sci-FiSci-Fi]
# 18  [ComedyComedy, MysteryMystery, SupernaturalSup...
# 19  [ActionAction, DramaDrama, FantasyFantasy, Mys...

# %%
unique_values = []
for genres in newdf["genres"]:
    if type(genres) != float:
        for genre in genres:
            if genre not in unique_values:
                unique_values.append(genre)

# %%
unique_values
# Out:
# ['ActionAction',
#  'AdventureAdventure',
#  'ComedyComedy',
#  'DramaDrama',
#  'FantasyFantasy',
#  'Sci-FiSci-Fi',
#  'MysteryMystery',
#  'SuspenseSuspense',
#  'RomanceRomance',
#  'SliceofLifeSliceofLife',
#  'SupernaturalSupernatural',
#  'SportsSports',
#  'HorrorHorror',
#  'EcchiEcchi',
#  'AvantGardeAvantGarde',
#  'BoysLoveBoysLove',
#  'GourmetGourmet',
#  'GirlsLoveGirlsLove',
#  'WorkLifeWorkLife']

# %%
for index, genres in enumerate(newdf["genres"]):
    new_genre = ""
    if type(genres) != float:
        for genre in genres:
            if genre == "ActionAction":
                new_genre += "Action"
            elif genre == "AdventureAdventure":
                new_genre += "Adventure"
            elif genre == "ComedyComedy":
                new_genre += "Comedy"
            elif genre == "DramaDrama":
                new_genre += "Drama"
            elif genre == "FantasyFantasy":
                new_genre += "Fantasy"
            elif genre == "Sci-FiSci-Fi":
                new_genre += "Sci-fi"
            elif genre == "MysteryMystery":
                new_genre += "Mystery"
            elif genre == "SuspenseSuspense":
                new_genre += "Suspense"
            elif genre == "RomanceRomance":
                new_genre += "Romance"
            elif genre == "SliceofLifeSliceofLife":
                new_genre += "SliceofLife"
            elif genre == "SupernaturalSupernatural":
                new_genre += "Supernatural"
            elif genre == "SportsSports":
                new_genre += "Sports"
            elif genre == "HorrorHorror":
                new_genre += "Horror"
            elif genre == "EcchiEcchi":
                new_genre += "Ecchi"
            elif genre == "AvantGardeAvantGarde":
                new_genre += "AvantGarde"
            elif genre == "BoysLoveBoysLove":
                new_genre += "BoysLove"
            elif genre == "GourmetGourmet":
                new_genre += "Gourmet"
            elif genre == "GirlsLoveGirlsLove":
                new_genre += "GirlsLove"
            elif genre == "WorkLifeWorkLife":
                new_genre += "WorkLife"
    newdf["genres"][index] = new_genre

# %%
";".join(re.findall('[A-Z][^A-Z]*', newdf["genres"][0]))
# Out:
# 'Action;Adventure;Comedy;Drama;Fantasy'

# %%
for index, genres in enumerate(newdf["genres"]):
    if type(genres) != float:
        newdf["genres"][index] = ";".join(re.findall('[A-Z][^A-Z]*', newdf["genres"][index]))

# %%
newdf.head(50)
# Out:
#                                                genres
# 0               Action;Adventure;Comedy;Drama;Fantasy
# 1                                Action;Comedy;Sci-fi
# 2                        Action;Drama;Fantasy;Mystery
# 3                               Drama;Sci-fi;Suspense
# 4      Comedy;Drama;Romance;Sliceof;Life;Supernatural
# 5                                Action;Comedy;Sci-fi
# 6                            Action;Adventure;Fantasy
# 7                                        Drama;Sci-fi
# 8                                Action;Comedy;Sci-fi
# 9                          Action;Comedy;Drama;Sci-fi
# 10                               Action;Comedy;Sci-fi
# 11                                 Drama;Sliceof;Life
# 12
# 13                         Drama;Fantasy;Sliceof;Life
# 14     Comedy;Drama;Romance;Sliceof;Life;Supernatural
# 15                               Action;Comedy;Sci-fi
# 16                               Action;Comedy;Sci-fi
# 17                                Action;Drama;Sci-fi
# 18                        Comedy;Mystery;Supernatural
# 19                       Action;Drama;Fantasy;Mystery
# 20                         Drama;Romance;Supernatural
# 21                               Action;Comedy;Sci-fi
# 22                                 Drama;Supernatural
# 23                                  Adventure;Fantasy
# 24            Action;Comedy;Sliceof;Life;Supernatural
# 25                               Action;Comedy;Sci-fi
# 26                                Comedy;Drama;Sports
# 27                        Action;Mystery;Supernatural
# 28                      Drama;Horror;Mystery;Suspense
# 29                       Adventure;Drama;Supernatural
# 30                Comedy;Mystery;Romance;Supernatural
# 31
# 32               Action;Adventure;Comedy;Drama;Sci-fi
# 33
# 34
# 35  Adventure;Fantasy;Mystery;Sliceof;Life;Superna...
# 36                          Action;Drama;Supernatural
# 37                        Action;Fantasy;Supernatural
# 38                                Comedy;Drama;Sports
# 39                             Action;Adventure;Drama
# 40                               Action;Drama;Romance
# 41                                Action;Supernatural
# 42                                Action;Drama;Sci-fi
# 43
# 44  Adventure;Fantasy;Mystery;Sliceof;Life;Superna...
# 45             Adventure;Drama;Fantasy;Mystery;Sci-fi
# 46                   Action;Drama;Sliceof;Life;Sports
# 47                                Action;Drama;Sci-fi
# 48                          Comedy;Drama;Sliceof;Life
# 49             Adventure;Drama;Fantasy;Mystery;Sci-fi

# %%
df.head()
# Out:
#                                  name  \
# 0    Fullmetal Alchemist: Brotherhood
# 1                             Gintama
# 2  Shingeki no Kyojin Season 3 Part 2
# 3                         Steins;Gate
# 4            Fruits Basket: The Final
#
#                                            producers  ranking  votersCount  \
# 0  Aniplex;SquareEnix;MainichiBroadcastingSystem;...        1      1629051
# 1                             TVTokyo;Aniplex;Dentsu        2       171695
# 2  ProductionI.G;Dentsu;MainichiBroadcastingSyste...        3      1108307
# 3  FrontierWorks;MediaFactory;Movic;AT-X;Kadokawa...        4      1115839
# 4  TVTokyo;TVOsaka;NihonAdSystems;Hakusensha;Avex...        5       118724
#
#    score  popularity  members  favorite  episodes animeType premiredDate  \
# 0   9.16           3  2689113    189880      64.0        TV  Spring 2009
# 1   9.09         336   487203     12881      51.0        TV  Spring 2015
# 2   9.09          33  1610148     45597      10.0        TV  Spring 2019
# 3   9.09          12  2100262    160985      24.0        TV  Spring 2011
# 4   9.06         630   279831     12851      13.0        TV  Spring 2021
#
#     animeSource                                             genres  \
# 0         Manga  ActionAction;AdventureAdventure;ComedyComedy;D...
# 1         Manga             ActionAction;ComedyComedy;Sci-FiSci-Fi
# 2         Manga  ActionAction;DramaDrama;FantasyFantasy;Mystery...
# 3  Visual novel           DramaDrama;Sci-FiSci-Fi;SuspenseSuspense
# 4         Manga  ComedyComedy;DramaDrama;RomanceRomance;Sliceof...
#
#                  studios                            licenses       rating  \
# 0                  Bones  ['Funimation', 'AniplexofAmerica']        R-17+
# 1  Bandai Namco Pictures       ['Funimation', 'Crunchyroll']  PG-13-Teens
# 2             Wit Studio                      ['Funimation']        R-17+
# 3              White Fox                      ['Funimation']  PG-13-Teens
# 4      TMS Entertainment                      ['Funimation']  PG-13-Teens
#
#                            voiceActorNameandLanguage  \
# 0  [['Kugimiya,Rie', 'Japanese'], ['Ponticelli,Be...
# 1  [['Kugimiya,Rie', 'Japanese'], ['Ishii,Kouji',...
# 2  [['Ishikawa,Yui', 'Japanese'], ['Perino,Elena'...
# 3  [['Seki,Tomokazu', 'Japanese'], ['Rinehart,Tys...
# 4  [['Iwami,Manaka', 'Japanese'], ['Uchida,Yuuma'...
#
#                               staffNameandOccupation
# 0  [['Cook,Justin', 'Producer'], ['Yonai,Noritomo...
# 1  [['Fujita,Youichi', 'Director,Storyboard,Plann...
# 2  [['Morishita,Katsuji', 'Producer,Planning'], [...
# 3  [['Iwasa,Gaku', 'Producer'], ['Yasuda,Takeshi'...
# 4  [['Ibata,Yoshihide', 'Director'], ['Aketagawa,...

# %%
df["genres"] = newdf["genres"]

# %%
df.head(20)
# Out:
#                                                  name  \
# 0                    Fullmetal Alchemist: Brotherhood
# 1                                             Gintama
# 2                  Shingeki no Kyojin Season 3 Part 2
# 3                                         Steins;Gate
# 4                            Fruits Basket: The Final
# 5                                            Gintama'
# 6                              Hunter x Hunter (2011)
# 7                                Ginga Eiyuu Densetsu
# 8                                 Gintama': Enchousen
# 9                                  Gintama: The Final
# 10                                           Gintama.
# 11                         3-gatsu no Lion 2nd Season
# 12                                     Koe no Katachi
# 13                            Violet Evergarden Movie
# 14                               Clannad: After Story
# 15                                            Gintama
# 16  Gintama Movie 2: Kanketsu-hen - Yorozuya yo Ei...
# 17                 Code Geass: Hangyaku no Lelouch R2
# 18                         Owarimonogatari 2nd Season
# 19               Shingeki no Kyojin: The Final Season
#
#                                             producers  ranking  votersCount  \
# 0   Aniplex;SquareEnix;MainichiBroadcastingSystem;...      1.0    1629051.0
# 1                              TVTokyo;Aniplex;Dentsu      2.0     171695.0
# 2   ProductionI.G;Dentsu;MainichiBroadcastingSyste...      3.0    1108307.0
# 3   FrontierWorks;MediaFactory;Movic;AT-X;Kadokawa...      4.0    1115839.0
# 4   TVTokyo;TVOsaka;NihonAdSystems;Hakusensha;Avex...      5.0     118724.0
# 5   TVTokyo;Aniplex;Dentsu;TrinitySound;MiracleRob...      6.0     179859.0
# 6                VAP;NipponTelevisionNetwork;Shueisha      7.0    1263852.0
# 7   TVTokyo;KittyFilms;TokumaShoten;TokumaJapanCom...      8.0      58559.0
# 8          TVTokyo;Aniplex;Dentsu;Shueisha;MiracleBus      9.0     130909.0
# 9                            TVTokyo;WarnerBros.Japan     10.0      31826.0
# 10                    TVTokyo;Aniplex;Dentsu;Shueisha     11.0     110051.0
# 11  Aniplex;Dentsu;NHK;Hakusensha;AsmikAce;"ToysFa...     12.0     156965.0
# 12   Shochiku;PonyCanyon;Kodansha;ABCAnimation;Quaras     13.0    1227199.0
# 13                                           Shochiku     14.0     104401.0
# 14               PonyCanyon;TBS;Rakuonsha;AnimationDo     15.0     570222.0
# 15  TVTokyo;Aniplex;Dentsu;TrinitySound;AudioHighs...     16.0     265054.0
# 16  TVTokyo;Aniplex;Dentsu;Bandai;WarnerBros.Japan...     17.0     110861.0
# 17  BandaiVisual;MainichiBroadcastingSystem;Bandai...     18.0     985084.0
# 18                                   Aniplex;Kodansha     19.0     152042.0
# 19  ProductionI.G;Dentsu;MainichiBroadcastingSyste...     20.0     812495.0
#
#     score  popularity    members  favorite  episodes animeType premiredDate  \
# 0    9.16         3.0  2689113.0  189880.0      64.0        TV  Spring 2009
# 1    9.09       336.0   487203.0   12881.0      51.0        TV  Spring 2015
# 2    9.09        33.0  1610148.0   45597.0      10.0        TV  Spring 2019
# 3    9.09        12.0  2100262.0  160985.0      24.0        TV  Spring 2011
# 4    9.06       630.0   279831.0   12851.0      13.0        TV  Spring 2021
# 5    9.06       381.0   431071.0    6466.0      51.0        TV  Spring 2011
# 6    9.06        10.0  2164151.0  166695.0     148.0        TV    Fall 2011
# 7    9.04       680.0   264114.0   13780.0     110.0       OVA          NaN
# 8    9.03       684.0   262390.0    2597.0      13.0        TV    Fall 2012
# 9    9.01      1902.0    80839.0    2900.0       1.0     Movie          NaN
# 10   8.98       723.0   247686.0    2363.0      12.0        TV  Winter 2017
# 11   8.97       526.0   325996.0   12987.0      22.0        TV    Fall 2017
# 12   8.97        23.0  1791624.0   68789.0       1.0     Movie          NaN
# 13   8.97       491.0   347050.0    4405.0       1.0     Movie          NaN
# 14   8.95       100.0  1028940.0   63871.0      24.0        TV    Fall 2008
# 15   8.95       123.0   890585.0   51543.0     201.0        TV  Spring 2006
# 16   8.94       924.0   196868.0    1956.0       1.0     Movie          NaN
# 17   8.91        46.0  1474898.0   67065.0      25.0        TV  Spring 2008
# 18   8.91       529.0   324908.0    7365.0       7.0        TV  Summer 2017
# 19   8.90        57.0  1359598.0   48207.0      16.0        TV  Winter 2021
#
#      animeSource                                          genres  \
# 0          Manga           Action;Adventure;Comedy;Drama;Fantasy
# 1          Manga                            Action;Comedy;Sci-fi
# 2          Manga                    Action;Drama;Fantasy;Mystery
# 3   Visual novel                           Drama;Sci-fi;Suspense
# 4          Manga  Comedy;Drama;Romance;Sliceof;Life;Supernatural
# 5          Manga                            Action;Comedy;Sci-fi
# 6          Manga                        Action;Adventure;Fantasy
# 7          Novel                                    Drama;Sci-fi
# 8          Manga                            Action;Comedy;Sci-fi
# 9          Manga                      Action;Comedy;Drama;Sci-fi
# 10         Manga                            Action;Comedy;Sci-fi
# 11         Manga                              Drama;Sliceof;Life
# 12         Manga
# 13   Light novel                      Drama;Fantasy;Sliceof;Life
# 14  Visual novel  Comedy;Drama;Romance;Sliceof;Life;Supernatural
# 15         Manga                            Action;Comedy;Sci-fi
# 16         Manga                            Action;Comedy;Sci-fi
# 17      Original                             Action;Drama;Sci-fi
# 18   Light novel                     Comedy;Mystery;Supernatural
# 19         Manga                    Action;Drama;Fantasy;Mystery
#
#                                 studios  \
# 0                                 Bones
# 1                 Bandai Namco Pictures
# 2                            Wit Studio
# 3                             White Fox
# 4                     TMS Entertainment
# 5                               Sunrise
# 6                              Madhouse
# 7   K-Factory, Kitty Film Mitaka Studio
# 8                               Sunrise
# 9                 Bandai Namco Pictures
# 10                Bandai Namco Pictures
# 11                                Shaft
# 12                      Kyoto Animation
# 13                      Kyoto Animation
# 14                      Kyoto Animation
# 15                              Sunrise
# 16                              Sunrise
# 17                              Sunrise
# 18                                Shaft
# 19                                MAPPA
#
#                                  licenses       rating  \
# 0      ['Funimation', 'AniplexofAmerica']        R-17+
# 1           ['Funimation', 'Crunchyroll']  PG-13-Teens
# 2                          ['Funimation']        R-17+
# 3                          ['Funimation']  PG-13-Teens
# 4                          ['Funimation']  PG-13-Teens
# 5                                     NaN  PG-13-Teens
# 6                            ['VIZMedia']  PG-13-Teens
# 7                     ['SentaiFilmworks']        R-17+
# 8                                     NaN  PG-13-Teens
# 9                          ['ElevenArts']  PG-13-Teens
# 10                                    NaN  PG-13-Teens
# 11                   ['AniplexofAmerica']  PG-13-Teens
# 12             ['ElevenArts', 'NYAVPost']  PG-13-Teens
# 13                         ['Funimation']  PG-13-Teens
# 14                    ['SentaiFilmworks']  PG-13-Teens
# 15     ['SentaiFilmworks', 'Crunchyroll']  PG-13-Teens
# 16                                    NaN  PG-13-Teens
# 17  ['Funimation', 'BandaiEntertainment']        R-17+
# 18                   ['AniplexofAmerica']        R-17+
# 19                         ['Funimation']        R-17+
#
#                             voiceActorNameandLanguage  \
# 0   [['Kugimiya,Rie', 'Japanese'], ['Ponticelli,Be...
# 1   [['Kugimiya,Rie', 'Japanese'], ['Ishii,Kouji',...
# 2   [['Ishikawa,Yui', 'Japanese'], ['Perino,Elena'...
# 3   [['Seki,Tomokazu', 'Japanese'], ['Rinehart,Tys...
# 4   [['Iwami,Manaka', 'Japanese'], ['Uchida,Yuuma'...
# 5   [['Kugimiya,Rie', 'Japanese'], ['Sugita,Tomoka...
# 6   [['Berger,Jackie', 'French'], ['Han,Megumi', '...
# 7   [['Inoue,Kazuhiko', 'Japanese'], ['Sakakibara,...
# 8   [['Kugimiya,Rie', 'Japanese'], ['Sugita,Tomoka...
# 9   [['Sugita,Tomokazu', 'Japanese'], ['Hino,Satos...
# 10  [['Kugimiya,Rie', 'Japanese'], ['Ishida,Akira'...
# 11  [['Kuno,Misaki', 'Japanese'], ['Huynh,Xanthe',...
# 12  [['Irino,Miyu', 'Japanese'], ['Matsuoka,Mayu',...
# 13  [['Donnay,Maxime', 'French'], ['Ishikawa,Yui',...
# 14  [['Nakahara,Mai', 'Japanese'], ['Christian,Luc...
# 15  [['Kugimiya,Rie', 'Japanese'], ['Mun,Seonhui',...
# 16  [['Kugimiya,Rie', 'Japanese'], ['Möller,KayaMa...
# 17  [['Yukana', 'Japanese'], ['Higgins,Kate', 'Eng...
# 18  [['Kamiya,Hiroshi', 'Japanese'], ['Katou,Emiri...
# 19  [['Ishikawa,Yui', 'Japanese'], ['Stefane,Mayar...
#
#                                staffNameandOccupation
# 0   [['Cook,Justin', 'Producer'], ['Yonai,Noritomo...
# 1   [['Fujita,Youichi', 'Director,Storyboard,Plann...
# 2   [['Morishita,Katsuji', 'Producer,Planning'], [...
# 3   [['Iwasa,Gaku', 'Producer'], ['Yasuda,Takeshi'...
# 4   [['Ibata,Yoshihide', 'Director'], ['Aketagawa,...
# 5   [['Fujita,Youichi', 'Director,EpisodeDirector,...
# 6   [['Maruyama,Masao', 'Producer'], ['Nakatani,To...
# 7   [['Ishiguro,Noboru', 'Director,EpisodeDirector...
# 8   [['Fujita,Youichi', 'Director,EpisodeDirector,...
# 9   [['Fujita,Youichi', 'Director'], ['Miyawaki,Ch...
# 10  [['Fujita,Youichi', 'Director'], ['Miyawaki,Ch...
# 11  [['Okada,Kenjirou', 'Director,EpisodeDirector,...
# 12  [['Senami,Riri', 'AssistantProducer'], ['Yamad...
# 13  [['Karasawa,Miho', 'ThemeSongPerformance'], ['...
# 14  [['Hatta,Youko', 'Producer'], ['Nakamura,Shini...
# 15  [['Takamatsu,Shinji', 'Co-Director,Director,St...
# 16  [['Fujita,Youichi', 'Director,EpisodeDirector,...
# 17  [['Maseba,Yutaka', 'Producer'], ['Taniguchi,Go...
# 18  [['Itamura,Tomoyuki', 'Director,EpisodeDirecto...
# 19  [['Hayashi,Yuuichirou', 'Director,Storyboard']...

# %%
df.loc[0, ["voiceActorNameandLanguage"]]
# Out:
# voiceActorNameandLanguage    [['Kugimiya,Rie', 'Japanese'], ['Ponticelli,Be...
# Name: 0, dtype: object

# %%
df["voiceActorNameandLanguage"][0]
# Out:
# "[['Kugimiya,Rie', 'Japanese'], ['Ponticelli,Benedetta', 'Italian'], ['Andreatto,Rodrigo', 'Portuguese(BR)'], ['Gerick,Wanja', 'German'], ['Baráth,István', 'Hungarian'], ['Whitehead,Maxey', 'English'], ['Yun,MiNa', 'Korean'], ['Truncale,Lily', 'English'], ['Torres,Jhonny', 'Spanish'], ['Pic,Audrey', 'French'], ['Boudonnat,Lucille', 'French'], ['Mignogna,Vic', 'English'], ['Park,Romi', 'Japanese'], ['Novara,Renato', 'Italian'], ['Scianca,Patrizia', 'Italian'], ['Campos,Marcelo', 'Portuguese(BR)'], ['Vieira,JoseManuel', 'Spanish'], ['Turba,David', 'German'], ['Szabó,Máté', 'Hungarian'], ['O,InSeong', 'Korean'], ['Hofmann,Muriel', 'English'], ['Pestel,Arthur', 'French'], ['Creton,François', 'French'], ['Utsumi,Kenji', 'Japanese'], ['Sabat,Christopher', 'English'], ['Zucca,Mario', 'Italian'], ['Baroli,Gilberto', 'Portuguese(BR)'], ['Faragó,András', 'Hungarian'], ['Allemane,Benoît', 'French'], ['Utsumi,Kenji', 'Japanese'], ['Sabat,Christopher', 'English'], ['Cruz,Walter', 'Portuguese(BR)'], ['Young,Stephanie', 'English'], ['Soumi,Youko', 'Japanese'], ['Lemes,Cecília', 'Portuguese(BR)'], ['Yang,JeongHwa', 'Korean'], ['Chevalot,Marie', 'French'], ['Kugimiya,Rie', 'Japanese'], ['Oxley,Kate', 'English'], ['Milani,Gabi', 'Portuguese(BR)'], ['Häcke,Maximiliane', 'German'], ['Jewell,Jerry', 'English'], ['Umezu,Hideyuki', 'Japanese'], ['Maise,Dieter', 'German'], ['Bottale,Luca', 'Italian'], ['Obermeyer,Arne', 'German'], ['Sodre,Elcio', 'Portuguese(BR)'], ['Ueda,Yuuji', 'Japanese'], ['Ayres,Greg', 'English'], ['Harting,Peter', 'German'], ['Guarnieri,JoséOtávio', 'Portuguese(BR)'], ['Shibata,Hidekatsu', 'Japanese'], ['Kiuchi,Hidenobu', 'Japanese'], ['Bevins,Christopher', 'English'], ['Blaylock,Ed', 'English'], ['Varga,Rókus', 'Hungarian'], ['Pichon,Yann', 'French'], ['Lobue,LuizAntônio', 'Portuguese(BR)'], ['Räuker,Erich', 'German'], ['Fallica,Raffaele', 'Italian'], ['DeSantis,Paolo', 'Italian'], ['Schultes,Dana', 'English'], ['Satou,Ai', 'Japanese'], ['deSá,Isabel', 'Portuguese(BR)'], ['Linderhaus,Silke', 'German'], ['Sanpei,Yuuko', 'Japanese'], ['Karbowski,Brittney', 'English'], ['Werner,Rieke', 'German'], ['Bienaimé,Nathalie', 'French'], ['Fantini,Silvana', 'Italian'], ['Luiz,Ítalo', 'Portuguese(BR)'], ['Inman,Jeremy', 'English'], ['Perez,LuisMiguel', 'Spanish'], ['Sato,Biichi', 'Japanese'], ['Andreozzi,Ruggero', 'Italian'], ['Campos,Ramon', 'Portuguese(BR)'], ['Sablik,Nico', 'German'], ['Hayashi,Yuuki', 'Japanese'], ['Foronda,Jim', 'English'], ['Beaucaire,Nicolas', 'French'], ['Araújo,Márcio', 'Portuguese(BR)'], ['Mantovani,Roger', 'Italian'], ['Ootomo,Ryuuzaburou', 'Japanese'], ['Parsons,Phil', 'English'], ['Indriago,Héctor', 'Spanish'], ['Lemarie,Sylvain', 'French'], ['Albertini,Stefano', 'Italian'], ['Martin,ThomasBalou', 'German'], ['Moreno,Antônio', 'Portuguese(BR)'], ['Shindo,Naomi', 'Japanese'], ['Marchi,Jamie', 'English'], ['Kiss,Virág', 'Hungarian'], ['Lima,MárciaRegina', 'Portuguese(BR)'], ['Rial,Monica', 'English'], ['Clerici,Serena', 'Italian'], ['Gotou,Mai', 'Japanese'], ['Lee,JiYeong', 'Korean'], ['Alencar,Bianca', 'Portuguese(BR)'], ['Truncale,Lily', 'English'], ['Estévez,MaríaJosé', 'Spanish'], ['Nishi,Rintarou', 'Japanese'], ['Wald,David', 'English'], ['Perón,Fernando', 'Portuguese(BR)'], ['Katou,Seizou', 'Japanese'], ['Mullins,Andy', 'English'], ['Lemarie,Sylvain', 'French'], ['Kuschmann,Bernd', 'German'], ['Balbi,Marco', 'Italian'], ['Lopes,Guilherme', 'Portuguese(BR)'], ['Fábio,Ricardo', 'Portuguese(BR)'], ['Wolf,Volker', 'German'], ['Egawa,Hisao', 'Japanese'], ['Auten,Christine', 'English'], ['Bizot,Hélène', 'French'], ['Tsuda,Shouko', 'Japanese'], ['Németh,Kriszta', 'Hungarian'], ['Gaidarji,Tânia', 'Portuguese(BR)'], ['Godoy,Citlalli', 'Spanish'], ['Leiße,Kordula', 'German'], ['Carter,Bob', 'English'], ['Sasaki,Seiji', 'Japanese'], ['Lemarie,Sylvain', 'French'], ['Castro,Mauro', 'Portuguese(BR)'], ['Albertini,Stefano', 'Italian'], ['Brink,Dieter', 'German'], ['Grelle,Josh', 'English'], ['Shouji,Masayuki', 'Japanese' ...
