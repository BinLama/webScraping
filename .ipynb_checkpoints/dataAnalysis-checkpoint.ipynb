# %%
import pandas as pd
import numpy as np
import matplotlib as mat

# %%
df = pd.read_csv("animeInfoComp.csv")

# %%
df.head()
# Out:
#                                  name  \
# 0    Fullmetal Alchemist: Brotherhood
# 1                             Gintama
# 2  Shingeki no Kyojin Season 3 Part 2
# 3                         Steins;Gate
# 4            Fruits Basket: The Final
#
#                                            producers  ranking  votersCount  \
# 0  ['Aniplex', 'SquareEnix', 'MainichiBroadcastin...        1      1629051
# 1                   ['TVTokyo', 'Aniplex', 'Dentsu']        2       171695
# 2  ['ProductionI.G', 'Dentsu', 'MainichiBroadcast...        3      1108307
# 3  ['FrontierWorks', 'MediaFactory', 'Movic', 'AT...        4      1115839
# 4  ['TVTokyo', 'TVOsaka', 'NihonAdSystems', 'Haku...        5       118724
#
#    score  popularity  members  favorite  episodes animeType premiredDate  \
# 0   9.16           3  2689113    189880      64.0        TV  Spring 2009
# 1   9.09         336   487203     12881      51.0        TV  Spring 2015
# ...

# %%
df.describe()
# Out:
#            ranking   votersCount        score    popularity       members  \
# count  6000.000000  6.000000e+03  6000.000000   6000.000000  6.000000e+03
# mean   3000.486167  5.661287e+04     7.241315   4140.003000  1.111075e+05
# std    1732.204548  1.454771e+05     0.504794   3064.254553  2.451961e+05
# min       1.000000  1.020000e+02     6.530000      1.000000  1.870000e+02
# 25%    1499.750000  2.617750e+03     6.830000   1641.750000  7.093250e+03
# 50%    3000.500000  1.062150e+04     7.170000   3512.500000  2.661450e+04
# 75%    4500.250000  4.306525e+04     7.540000   6135.250000  9.993225e+04
# max    6000.000000  2.195444e+06     9.160000  16611.000000  3.168917e+06
#
#             favorite     episodes
# count    6000.000000  5970.000000
# mean     1394.658333    14.946734
# std      7322.350279    35.644869
# min         0.000000     1.000000
# 25%        11.000000     1.000000
# 50%        53.000000    10.000000
# 75%       347.250000    13.000000
# ...
